# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

# %%
plt.plot(xpoints, ypoints, marker = 'o')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '*')
plt.show()

# %%
plt.plot(xpoints, ypoints, '*')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '.')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = ',')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'x')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'X')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '+')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'P')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 's')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'D')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'd')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'p')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'h')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'H')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '>')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '<')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '1')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '2')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '3')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '4')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '|')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = '_')
plt.show()

# %%
plt.plot(xpoints, ypoints, '-')
plt.show()

# %%
plt.plot(xpoints, ypoints, ':')
plt.show()

# %%
plt.plot(xpoints, ypoints, '--')
plt.show()

# %%
plt.plot(xpoints, ypoints, '-.')
plt.show()

# %%
plt.plot(xpoints, ypoints, '-')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-r')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-g')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-b')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-c')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-m')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-y')
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o-k')
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'o', markerfacecolor = 'yellow', markeredgecolor = 'black', markersize = 20)
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'o', mfc = 'y', mec = 'k', ms = 20)
plt.show()

# %%
plt.plot(xpoints, ypoints, m = 'o', mfc = 'y', mec = 'k', ms = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 plt.plot(xpoints, ypoints, m = 'o', mfc = 'y', mec = 'k', ms = 20)
#       2 plt.show()
#
# File c:\Users\G M RIFAT REZA\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# File c:\Users\G M RIFAT REZA\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...

# %%
plt.plot(xpoints, ypoints, marker = 'o', color = 'r', mfc = 'y', mec = 'k', ms = 20)
plt.show()

# %%
plt.plot(xpoints, ypoints, marker = 'o', c = 'r', mfc = 'y', mec = 'k', ms = 20)
plt.show()

# %%
plt.plot(xpoints, ypoints, lw = 2 , c = 'r', marker = 'o', mfc = 'y', mec = 'k', ms = 20)
plt.show()

# %%
plt.plot(xpoints, ypoints, lw = 20 , c = 'r', marker = 'o', mfc = 'y', mec = 'k', ms = 20)
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)
y2 = pow(x, 3)

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)
y2 = pow(x, 3)

plt.plot(x, y1, x, y2)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)
y2 = pow(x, 3)

plt.plot(x, y1, y1, y2)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

plt.plot(x, y1)
plt.xlabel("X")
plt.ylabel('X square')
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

plt.plot(x, y1)
plt.title('Graph o x square')
plt.xlabel("X")
plt.ylabel('X square')
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1)
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.plot(x, y1)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1, loc = 'right')
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.plot(x, y1)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1, loc = 'right')
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.grid()
plt.plot(x, y1)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1, loc = 'right')
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.grid(axis = 'x')
plt.plot(x, y1)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1, loc = 'right')
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.grid(axis = 'y')
plt.plot(x, y1)
plt.show()

# %%
x = np.arange(0, 11, 1)
y1 = pow(x, 2)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


plt.title('Graph o x square', fontdict = font1, loc = 'right')
plt.xlabel("X", fontdict = font2)
plt.ylabel('X square', fontdict = font2)

plt.grid(color = 'g', ls = '--', lw = '1')
plt.plot(x, y1)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.plot(x, y, 'o')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, color=colors)

plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', linestyle='-')

# Add annotations
for i, (xi, yi) in enumerate(zip(x, y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(0, 5), ha='center')

plt.title('Line Chart with Annotations')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

plt.grid(True)
plt.show()

# %%
for i in zip(x, y):
    print(i)
# Out:
# (1, 2)
# (2, 4)
# (3, 6)
# (4, 8)
# (5, 10)
